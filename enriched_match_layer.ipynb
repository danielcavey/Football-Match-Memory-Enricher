# %%
import json

with open("match.json") as f:
    data = json.load(f)



data
# Out:
# {'goals': [{'minute': '25', 'player': 'Tevez', 'team': 'Manchester United'}],
#  'red cards': [],
#  'home manager': 'Alex McLeish',
#  'away manager': 'Sir Alex Ferguson',
#  'man of the match': 'Carlos Tevez'}

# %%
data["home manager"]
# Out:
# 'Alex McLeish'
